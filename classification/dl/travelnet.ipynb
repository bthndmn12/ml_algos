# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from torchvision import datasets, transforms
import time

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")


hidden_size = 64
output_size = 10
beta_init = 1e-4
learning_rate = 1e-4 
dt = 1e-4
num_epochs = 100 
dropout_rate = 0.3  

# basic demonstration of travel wave net(it is not a real implementation) 

class TravelingWaveLayer(nn.Module):
    def __init__(self, input_size, output_size, beta_init):
        super(TravelingWaveLayer, self).__init__()
        self.w = nn.Parameter(torch.randn(output_size, input_size) * 0.001)
        self.beta = nn.Parameter(torch.tensor(beta_init).float().to(device))
        self.x = torch.arange(input_size, dtype=torch.float).unsqueeze(0).to(device)

    def forward(self, x, t):
        w2 = self.w * (self.x * torch.cosh(5*self.beta) + t * torch.sinh(5*self.beta)).unsqueeze(1)
        return torch.matmul(w2, x.unsqueeze(-1)).squeeze(-1)


    def update_beta(self, dt):
        with torch.no_grad():
            beta_xx = (torch.roll(self.beta, -1) - 2*self.beta + torch.roll(self.beta, 1))
            beta_t = (self.beta - self.beta.clone().detach()) / dt
            self.beta.data += dt * (beta_t - beta_xx + self.beta - self.beta**3 - 0.01 * self.beta)  
            self.beta.data = torch.clamp(self.beta.data, -0.10, 0.10) 

class TravelingWaveNN(nn.Module):
    def __init__(self, output_size, beta_init, dropout_rate):
        super(TravelingWaveNN, self).__init__()

        self.input_size = 28 * 28 

        self.wave_layer1 = TravelingWaveLayer(self.input_size, hidden_size // 2, beta_init)
        self.wave_layer2 = TravelingWaveLayer(hidden_size // 2, hidden_size // 4, beta_init)
        self.wave_layer3 = TravelingWaveLayer(hidden_size // 4, hidden_size // 2, beta_init)
        self.wave_layer4 = TravelingWaveLayer(hidden_size // 2, output_size, beta_init)
        self.wave_layer5 = TravelingWaveLayer(output_size, output_size, beta_init)
        


        self.t1 = nn.Parameter(torch.tensor([0.9], device=device))
        self.t2 = nn.Parameter(torch.tensor([0.9], device=device))
        self.t3 = nn.Parameter(torch.tensor([0.9], device=device))
        self.t4 = nn.Parameter(torch.tensor([0.9], device=device))
        self.t5 = nn.Parameter(torch.tensor([0.9], device=device))

    def forward(self, x):
        x = x.view(x.size(0), -1)
        x = self.wave_layer1(x, self.t1)
        x = self.wave_layer2(x, self.t2)
        x = self.wave_layer3(x, self.t3)
        x = self.wave_layer4(x, self.t4)
        x = self.wave_layer5(x, self.t5)
        return x

train_dataset = datasets.MNIST(root='./data', 
                               train=True, 
                               download=True, 
                               transform=transforms.ToTensor()) 
test_dataset = datasets.MNIST(root='./data', 
                              train=False, 
                              download=True, 
                              transform=transforms.ToTensor())

train_loader = DataLoader(train_dataset, batch_size=128, shuffle=True, num_workers=4)
test_loader = DataLoader(test_dataset, batch_size=1000, shuffle=False, num_workers=4)

model = TravelingWaveNN(output_size, beta_init, dropout_rate).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

max_grad_norm = 1.0  

for epoch in range(num_epochs):
    start_time = time.time()
    train_loss = 0
    correct = 0
    model.train()
    for batch_idx, (data, target) in enumerate(train_loader):
        data, target = data.to(device), target.to(device)

        optimizer.zero_grad()
        output = model(data)
        loss = criterion(output, target)
        loss.backward()

        torch.nn.utils.clip_grad_norm_(model.parameters(), max_grad_norm)
        optimizer.step()

        model.wave_layer1.update_beta(dt)
        model.wave_layer2.update_beta(dt)  
        model.wave_layer3.update_beta(dt)
        model.wave_layer4.update_beta(dt)
        model.wave_layer5.update_beta(dt)

        train_loss += loss.item() * data.size(0)
        pred = output.argmax(dim=1, keepdim=True)
        correct += pred.eq(target.view_as(pred)).sum().item()
    train_loss /= len(train_loader.dataset)
    train_accuracy = 100. * correct / len(train_loader.dataset)
    
    test_loss = 0
    correct = 0
    with torch.no_grad():
        for data, target in test_loader:
            data, target = data.to(device), target.to(device)
            output = model(data)
            test_loss += criterion(output, target).item()
            pred = output.argmax(dim=1, keepdim=True)
            correct += pred.eq(target.view_as(pred)).sum().item()

    test_loss /= len(test_loader.dataset)
    test_accuracy = 100. * correct / len(test_loader.dataset)
    print(f"Epoch {epoch+1}/{num_epochs}, Loss: {train_loss:.4f}, Accuracy: {train_accuracy:.0f}%, Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.0f}%, Time: {time.time() - start_time:.2f}s")

model.eval()
test_loss = 0
correct = 0
with torch.no_grad():
    for data, target in test_loader:
        data, target = data.to(device), target.to(device)
        output = model(data)
        test_loss += criterion(output, target).item()
        pred = output.argmax(dim=1, keepdim=True)
        correct += pred.eq(target.view_as(pred)).sum().item()

test_loss /= len(test_loader.dataset)
test_accuracy = 100. * correct / len(test_loader.dataset)
print(f'\nTest set: Average loss: {test_loss:.4f}, Accuracy: {test_accuracy:.0f}%')
# Out:
# Using device: cuda
# Epoch 1/100, Loss: 1.3238, Accuracy: 47%, Test Loss: 0.0011, Test Accuracy: 59%, Time: 3.39s
# Epoch 2/100, Loss: 1.0588, Accuracy: 61%, Test Loss: 0.0011, Test Accuracy: 62%, Time: 3.16s
# Epoch 3/100, Loss: 0.9866, Accuracy: 65%, Test Loss: 0.0007, Test Accuracy: 78%, Time: 3.18s
# Epoch 4/100, Loss: 0.7185, Accuracy: 78%, Test Loss: 0.0007, Test Accuracy: 79%, Time: 3.16s
# Epoch 5/100, Loss: 0.7046, Accuracy: 79%, Test Loss: 0.0007, Test Accuracy: 79%, Time: 3.25s
# Epoch 6/100, Loss: 0.6996, Accuracy: 79%, Test Loss: 0.0007, Test Accuracy: 80%, Time: 3.17s
# Epoch 7/100, Loss: 0.6850, Accuracy: 80%, Test Loss: 0.0005, Test Accuracy: 84%, Time: 3.14s
# Epoch 8/100, Loss: 0.4896, Accuracy: 86%, Test Loss: 0.0005, Test Accuracy: 86%, Time: 3.26s
# Epoch 9/100, Loss: 0.4712, Accuracy: 87%, Test Loss: 0.0005, Test Accuracy: 86%, Time: 3.23s
# Epoch 10/100, Loss: 0.4662, Accuracy: 87%, Test Loss: 0.0005, Test Accuracy: 86%, Time: 3.23s
# Epoch 11/100, Loss: 0.4634, Accuracy: 87%, Test Loss: 0.0005, Test Accuracy: 87%, Time: 3.22s
# Epoch 12/100, Loss: 0.4610, Accuracy: 87%, Test Loss: 0.0005, Test Accuracy: 87%, Time: 3.24s
# Epoch 13/100, Loss: 0.4585, Accuracy: 87%, Test Loss: 0.0005, Test Accuracy: 87%, Time: 3.38s
# Epoch 14/100, Loss: 0.4573, Accuracy: 87%, Test Loss: 0.0005, Test Accuracy: 87%, Time: 3.54s
# Epoch 15/100, Loss: 0.4578, Accuracy: 87%, Test Loss: 0.0005, Test Accuracy: 86%, Time: 3.19s
# Epoch 16/100, Loss: 0.4570, Accuracy: 87%, Test Loss: 0.0005, Test Accuracy: 87%, Time: 3.15s
# Epoch 17/100, Loss: 0.4570, Accuracy: 87%, Test Loss: 0.0005, Test Accuracy: 87%, Time: 3.33s
# Epoch 18/100, Loss: 0.4545, Accuracy: 87%, Test Loss: 0.0005, Test Accuracy: 87%, Time: 3.12s
# Epoch 19/100, Loss: 0.4541, Accuracy: 87%, Test Loss: 0.0005, Test Accuracy: 87%, Time: 3.32s
# Epoch 20/100, Loss: 0.4537, Accuracy: 87%, Test Loss: 0.0005, Test Accuracy: 87%, Time: 3.16s
# Epoch 21/100, Loss: 0.4539, Accuracy: 87%, Test Loss: 0.0005, Test Accuracy: 87%, Time: 3.27s
# Epoch 22/100, Loss: 0.4518, Accuracy: 87%, Test Loss: 0.0005, Test Accuracy: 87%, Time: 3.13s
# Epoch 23/100, Loss: 0.4511, Accuracy: 87%, Test Loss: 0.0005, Test Accuracy: 87%, Time: 3.26s
# Epoch 24/100, Loss: 0.4300, Accuracy: 88%, Test Loss: 0.0004, Test Accuracy: 89%, Time: 3.33s
# Epoch 25/100, Loss: 0.3799, Accuracy: 89%, Test Loss: 0.0004, Test Accuracy: 89%, Time: 3.17s
# Epoch 26/100, Loss: 0.3716, Accuracy: 90%, Test Loss: 0.0004, Test Accuracy: 89%, Time: 3.22s
# Epoch 27/100, Loss: 0.3679, Accuracy: 90%, Test Loss: 0.0004, Test Accuracy: 90%, Time: 3.21s
# Epoch 28/100, Loss: 0.3665, Accuracy: 90%, Test Loss: 0.0004, Test Accuracy: 90%, Time: 3.19s
# Epoch 29/100, Loss: 0.3663, Accuracy: 90%, Test Loss: 0.0004, Test Accuracy: 90%, Time: 3.16s
# Epoch 30/100, Loss: 0.3657, Accuracy: 90%, Test Loss: 0.0004, Test Accuracy: 89%, Time: 3.11s
# Epoch 31/100, Loss: 0.3635, Accuracy: 90%, Test Loss: 0.0004, Test Accuracy: 90%, Time: 3.24s
# Epoch 32/100, Loss: 0.3631, Accuracy: 90%, Test Loss: 0.0004, Test Accuracy: 89%, Time: 3.23s
# Epoch 33/100, Loss: 0.3634, Accuracy: 90%, Test Loss: 0.0004, Test Accuracy: 89%, Time: 3.46s
# Epoch 34/100, Loss: 0.3571, Accuracy: 90%, Test Loss: 0.0004, Test Accuracy: 90%, Time: 3.24s
# Epoch 35/100, Loss: 0.3329, Accuracy: 91%, Test Loss: 0.0004, Test Accuracy: 90%, Time: 3.15s
# Epoch 36/100, Loss: 0.3226, Accuracy: 91%, Test Loss: 0.0003, Test Accuracy: 91%, Time: 3.30s
# Epoch 37/100, Loss: 0.3196, Accuracy: 91%, Test Loss: 0.0003, Test Accuracy: 91%, Time: 3.33s
# Epoch 38/100, Loss: 0.3152, Accuracy: 91%, Test Loss: 0.0003, Test Accuracy: 90%, Time: 3.21s
# Epoch 39/100, Loss: 0.3148, Accuracy: 91%, Test Loss: 0.0003, Test Accuracy: 91%, Time: 3.43s
# Epoch 40/100, Loss: 0.3126, Accuracy: 91%, Test Loss: 0.0003, Test Accuracy: 91%, Time: 3.26s
# Epoch 41/100, Loss: 0.3116, Accuracy: 91%, Test Loss: 0.0003, Test Accuracy: 90%, Time: 3.12s
# Epoch 42/100, Loss: 0.3106, Accuracy: 91%, Test Loss: 0.0003, Test Accuracy: 91%, Time: 3.12s
# Epoch 43/100, Loss: 0.3113, Accuracy: 91%, Test Loss: 0.0003, Test Accuracy: 91%, Time: 3.22s
# Epoch 44/100, Loss: 0.3118, Accuracy: 91%, Test Loss: 0.0003, Test Accuracy: 91%, Time: 3.18s
# Epoch 45/100, Loss: 0.3094, Accuracy: 91%, Test Loss: 0.0003, Test Accuracy: 91%, Time: 3.30s
# Epoch 46/100, Loss: 0.3043, Accuracy: 92%, Test Loss: 0.0003, Test Accuracy: 91%, Time: 3.23s
# Epoch 47/100, Loss: 0.2924, Accuracy: 92%, Test Loss: 0.0003, Test Accuracy: 91%, Time: 3.23s
# Epoch 48/100, Loss: 0.2898, Accuracy: 92%, Test Loss: 0.0003, Test Accuracy: 92%, Time: 3.22s
# Epoch 49/100, Loss: 0.2855, Accuracy: 92%, Test Loss: 0.0003, Test Accuracy: 91%, Time: 3.37s
# Epoch 50/100, Loss: 0.2849, Accuracy: 92%, Test Loss: 0.0003, Test Accuracy: 91%, Time: 3.27s
# Epoch 51/100, Loss: 0.2853, Accuracy: 92%, Test Loss: 0.0003, Test Accuracy: 91%, Time: 3.15s
# Epoch 52/100, Loss: 0.2832, Accuracy: 92%, Test Loss: 0.0003, Test Accuracy: 92%, Time: 3.20s
# Epoch 53/100, Loss: 0.2826, Accuracy: 92%, Test Loss: 0.0003, Test Accuracy: 91%, Time: 3.21s
# Epoch 54/100, Loss: 0.2800, Accuracy: 92%, Test Loss: 0.0003, Test Accuracy: 92%, Time: 3.16s
# Epoch 55/100, Loss: 0.2781, Accuracy: 92%, Test Loss: 0.0003, Test Accuracy: 92%, Time: 3.49s
# Epoch 56/100, Loss: 0.2740, Accuracy: 92%, Test Loss: 0.0003, Test Accuracy: 92%, Time: 3.12s
# Epoch 57/100, Loss: 0.2719, Accuracy: 92%, Test Loss: 0.0003, Test Accuracy: 92%, Time: 3.26s
# Epoch 58/100, Loss: 0.2706, Accuracy: 93%, Test Loss: 0.0003, Test Accuracy: 92%, Time: 3.25s
# Epoch 59/100, Loss: 0.2697, Accuracy: 93%, Test Loss: 0.0003, Test Accuracy: 92%, Time: 3.56s
# Epoch 60/100, Loss: 0.2672, Accuracy: 93%, Test Loss: 0.0003, Test Accuracy: 92%, Time: 3.19s
# Epoch 61/100, Loss: 0.2648, Accuracy: 93%, Test Loss: 0.0003, Test Accuracy: 92%, Time: 3.15s
# Epoch 62/100, Loss: 0.2622, Accuracy: 93%, Test Loss: 0.0003, Test Accuracy: 92%, Time: 3.25s
# Epoch 63/100, Loss: 0.2624, Accuracy: 93%, Test Loss: 0.0003, Test Accuracy: 92%, Time: 3.21s
# Epoch 64/100, Loss: 0.2601, Accuracy: 93%, Test Loss: 0.0003, Test Accuracy: 92%, Time: 3.23s
# Epoch 65/100, Loss: 0.2604, Accuracy: 93%, Test Loss: 0.0003, Test Accuracy: 92%, Time: 3.27s
# Epoch 66/100, Loss: 0.2580, Accuracy: 93%, Test Loss: 0.0003, Test Accuracy: 92%, Time: 3.15s
# Epoch 67/100, Loss: 0.2577, Accuracy: 93%, Test Loss: 0.0003, Test Accuracy: 92%, Time: 3.27s
# Epoch 68/100, Loss: 0.2579, Accuracy: 93%, Test Loss: 0.0003, Test Accuracy: 92%, Time: 3.18s
# Epoch 69/100, Loss: 0.2575, Accuracy: 93%, Test Loss: 0.0003, Test Accuracy: 92%, Time: 3.31s
# Epoch 70/100, Loss: 0.2567, Accuracy: 93%, Test Loss: 0.0003, Test Accuracy: 92%, Time: 3.37s
# Epoch 71/100, Loss: 0.2567, Accuracy: 93%, Test Loss: 0.0003, Test Accuracy: 92%, Time: 3.24s
# Epoch 72/100, Loss: 0.2567, Accuracy: 93%, Test Loss: 0.0003, Test Accuracy: 92%, Time: 3.30s
# Epoch 73/100, Loss: 0.2545, Accuracy: 93%, Test Loss: 0.0003, Test Accuracy: 92%, Time: 3.25s
# Epoch 74/100, Loss: 0.2551, Accuracy: 93%, Test Loss: 0.0003, Test Accuracy: 92%, Time: 3.29s
# Epoch 75/100, Loss: 0.2542, Accuracy: 93%, Test Loss: 0.0003, Test Accuracy: 92%, Time: 3.23s
# Epoch 76/100, Loss: 0.2536, Accuracy: 93%, Test Loss: 0.0003, Test Accuracy: 92%, Time: 3.18s
# Epoch 77/100, Loss: 0.2534, Accuracy: 93%, Test Loss: 0.0003, Test Accuracy: 92%, Time: 3.37s
# Epoch 78/100, Loss: 0.2538, Accuracy: 93%, Test Loss: 0.0003, Test Accuracy: 92%, Time: 3.27s
# Epoch 79/100, Loss: 0.2528, Accuracy: 93%, Test Loss: 0.0003, Test Accuracy: 92%, Time: 3.16s
# Epoch 80/100, Loss: 0.2531, Accuracy: 93%, Test Loss: 0.0003, Test Accuracy: 92%, Time: 3.23s
# Epoch 81/100, Loss: 0.2520, Accuracy: 93%, Test Loss: 0.0003, Test Accuracy: 92%, Time: 3.22s
# Epoch 82/100, Loss: 0.2522, Accuracy: 93%, Test Loss: 0.0003, Test Accuracy: 92%, Time: 3.12s
# Epoch 83/100, Loss: 0.2510, Accuracy: 93%, Test Loss: 0.0003, Test Accuracy: 92%, Time: 3.21s
# Epoch 84/100, Loss: 0.2521, Accuracy: 93%, Test Loss: 0.0003, Test Accuracy: 92%, Time: 3.25s
# Epoch 85/100, Loss: 0.2519, Accuracy: 93%, Test Loss: 0.0003, Test Accuracy: 92%, Time: 3.28s
# Epoch 86/100, Loss: 0.2517, Accuracy: 93%, Test Loss: 0.0003, Test Accuracy: 92%, Time: 3.28s
# Epoch 87/100, Loss: 0.2513, Accuracy: 93%, Test Loss: 0.0003, Test Accuracy: 92%, Time: 3.30s
# Epoch 88/100, Loss: 0.2507, Accuracy: 93%, Test Loss: 0.0003, Test Accuracy: 92%, Time: 3.28s
# Epoch 89/100, Loss: 0.2509, Accuracy: 93%, Test Loss: 0.0003, Test Accuracy: 92%, Time: 3.15s
# Epoch 90/100, Loss: 0.2508, Accuracy: 93%, Test Loss: 0.0003, Test Accuracy: 92%, Time: 3.16s
# Epoch 91/100, Loss: 0.2500, Accuracy: 93%, Test Loss: 0.0003, Test Accuracy: 92%, Time: 3.13s
# Epoch 92/100, Loss: 0.2504, Accuracy: 93%, Test Loss: 0.0003, Test Accuracy: 92%, Time: 3.39s
# Epoch 93/100, Loss: 0.2496, Accuracy: 93%, Test Loss: 0.0003, Test Accuracy: 92%, Time: 3.23s
# Epoch 94/100, Loss: 0.2494, Accuracy: 93%, Test Loss: 0.0003, Test Accuracy: 92%, Time: 3.38s
# Epoch 95/100, Loss: 0.2501, Accuracy: 93%, Test Loss: 0.0003, Test Accuracy: 92%, Time: 3.25s
# Epoch 96/100, Loss: 0.2484, Accuracy: 93%, Test Loss: 0.0003, Test Accuracy: 92%, Time: 3.52s
# Epoch 97/100, Loss: 0.2482, Accuracy: 93%, Test Loss: 0.0003, Test Accuracy: 92%, Time: 3.28s
# Epoch 98/100, Loss: 0.2492, Accuracy: 93%, Test Loss: 0.0003, Test Accuracy: 92%, Time: 3.24s
# Epoch 99/100, Loss: 0.2491, Accuracy: 93%, Test Loss: 0.0003, Test Accuracy: 92%, Time: 3.20s
# Epoch 100/100, Loss: 0.2490, Accuracy: 93%, Test Loss: 0.0003, Test Accuracy: 92%, Time: 3.26s
#
# Test set: Average loss: 0.0003, Accuracy: 92%
